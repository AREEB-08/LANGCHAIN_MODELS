# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.10

# %%
import numpy
import sklearn
from dotenv import load_dotenv

# %%
print(numpy.__version__)
print(sklearn.__version__)
# Out:
# 2.4.2
# 1.8.0

# %%
import sys
print(sys.executable)
# Out:
# d:\code floders\PYTHON-5\LANGCHAIN_MODELS\new_environment\Scripts\python.exe

# %%
from dotenv import load_dotenv
import os

load_dotenv()

print(os.getenv("OPENAI_API_KEY"))
# Out:
# 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
